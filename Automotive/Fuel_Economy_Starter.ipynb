# %% [markdown]
# # Fuel Economy Problem Statement Starter
#
# This notebook is the student-facing starter for the vehicle fuel economy problem statement based on `vehicles.csv`.
#
# Expected topics:
#
# - data cleansing
# - visualization
# - feature engineering
# - classification
# - regression
# - computer vision with YOLO
# - RAG search and a local Ollama model
# - Streamlit deployment
#
# Keep your final analysis in this notebook and attach any supporting files needed to run your app.

# %%
# Recommended environment setup
# %pip install pandas numpy scikit-learn matplotlib seaborn streamlit ultralytics ollama pillow
#
# Start Ollama in a terminal and pull a local model of your choice:
#   ollama serve
#   ollama pull gemma4:e4b

# %% [markdown]
# ## 1. Load and Inspect the Dataset
#
# Prompt:
#
# - Load `vehicles.csv`.
# - Report the number of rows, columns, and the range of model years.
# - Identify at least five columns that look useful for modeling.
# - Identify at least five columns that appear sparse, noisy, or likely to cause leakage.

# %%
# TODO: import the libraries you need and load vehicles.csv into a DataFrame.

# %% [markdown]
# ## 2. Data Cleansing
#
# Prompt:
#
# - Remove duplicates when appropriate.
# - Convert numeric columns to numeric types.
# - Standardize important text fields.
# - Decide how you will handle missing values.
# - Briefly justify any columns you drop.
#
# Suggestions:
#
# - Distinguish between truly missing values and structurally missing values. For example, electrified vehicles may not have conventional engine cylinders or displacement.
# - Document any target cleansing you perform before regression.
# - Watch for columns that may leak the answer because they are derived from MPG, fuel use, or emissions.
#
# You should document your cleansing assumptions in markdown.

# %%
# TODO: write a cleaning function.
# Suggested ideas:
# - collapse drivetrain labels into a smaller set
# - extract gear count from trany
# - create flags for turbo, supercharger, start-stop, or electrified vehicles
# - create an efficiency label such as comb08 >= 24

def clean_vehicle_data(df):
    df = df.copy()

    # TODO: implement your cleaning steps here.

    return df

# %% [markdown]
# ## 3. Visualization
#
# Prompt:
#
# Create at least three visualizations that help explain the dataset. Include a short interpretation after each one.
#
# Suggested plot ideas:
#
# - combined MPG by fuel type
# - engine displacement versus combined MPG
# - median MPG over time
# - annual fuel cost or emissions by vehicle class

# %%
# TODO: generate at least three plots and interpret them.

# %% [markdown]
# ## 4. Feature Engineering
#
# Prompt:
#
# Build a modeling table that avoids direct leakage from the regression targets.
#
# Recommended candidate features include:
#
# - `year` or `vehicle_age`
# - `make`, `VClass`, and grouped `fuelType1`
# - grouped `drive` and `trany`
# - `cylinders`, `displ`, and extracted `gear_count`
# - engineered flags such as turbo, supercharger, start-stop, electrified, and AWD indicators
#
# Requirements:
#
# - explain which features you keep
# - explain which fields you exclude and why
# - create at least three engineered features
# - justify whether the same feature set should be reused for both classification and regression

# %%
# TODO: define your feature columns and prepare the modeling table.

feature_cols = []
target_class = "efficiency_label"
target_regression_1 = "comb08"
target_regression_2 = "co2TailpipeGpm"  # or justify another interesting continuous target

# %% [markdown]
# ## 5. Classification
#
# Prompt:
#
# Train a classification model that predicts whether a vehicle is high efficiency.
#
# Minimum expectations:
#
# - use an 80/20 train-test split
# - compare at least two classifiers
# - report accuracy, F1 score, and a confusion matrix
# - rank the candidate predictors with `SelectKBest` and discuss the most important classification features

# %%
# TODO: build your classification workflow here.
# Suggested models: Logistic Regression, Random Forest, XGBoost, or another supervised classifier.
# Also use SelectKBest(score_func=f_classif) to rank the most informative encoded predictors.

# %% [markdown]
# ## 6. Regression
#
# Prompt:
#
# Train regression models for:
#
# - `comb08` (combined MPG)
# - one additional interesting continuous target from the dataset
#
# Minimum expectations:
#
# - inspect the target distribution and cleanse unrealistic or unsupported label values before training
# - handle the fact that electrified vehicles have structurally missing engine fields and may need separate treatment from combustion vehicles
# - consider whether separate regressors for electrified and internal combustion vehicles improve performance
# - use an 80/20 train-test split
# - compare at least two regressors
# - report MAE, RMSE, and R2
# - compare predicted versus actual values
# - rank the MPG predictors with `SelectKBest` and discuss which features matter most

# %%
# TODO: build your regression workflow here.
# Suggested models: Linear Regression, Random Forest Regressor, Gradient Boosting, or XGBoost Regressor.
# Also use SelectKBest(score_func=f_regression) to rank the most informative encoded MPG predictors.
# If a single MPG model collapses toward unrealistic values, cleanse the labels and
# consider separate regressors for electrified and internal combustion vehicles.

# %% [markdown]
# ## 7. Computer Vision with YOLO
#
# Prompt:
#
# Use a pretrained YOLO model to verify that an uploaded image contains a car.
#
# Requirements:
#
# - use the COCO `car` class with object ID `2`
# - display the detections on the image
# - describe how this vision step fits into your vehicle prediction workflow
#
# Note:
#
# The dataset does not provide vehicle images, so YOLO is used here as an image verification step before the user continues with the app.

# %%
# TODO: load a pretrained YOLO model and write a helper function such as detect_cars_with_yolo(image_path).
# Suggested package: ultralytics

CAR_CLASS_ID = 2

# %% [markdown]
# ## 8. RAG Search and Ollama
#
# Prompt:
#
# Build a local retrieval-augmented generation workflow that answers questions about the selected vehicle.
#
# Requirements:
#
# - create a text knowledge base from the dataset
# - retrieve relevant context for the selected vehicle
# - call a local Ollama model with the Python `ollama` package
# - instruct the model to answer only from the retrieved context
# - show the retrieved context in your notebook or app

# %%
# TODO: build a local RAG workflow.
# You may use TF-IDF or embeddings for retrieval, but the retrieval must be local.
# Then call a local Ollama model with the Python ollama package, such as llama3.1:8b.

OLLAMA_MODEL = "gemma4:e4b"

# %% [markdown]
# ## 9. Streamlit App
#
# Prompt:
#
# Design a Streamlit app that:
#
# - selects from `year`, `make`, and `model` in the dataset
# - handles duplicate trims when those three fields are not unique
# - predicts fuel efficiency and one additional target
# - shows measured MPG relative to predicted MPG on the dashboard
# - optionally verifies an uploaded image with YOLO
# - uses RAG + Ollama to answer a user question about the selected car
#
# Suggestion:
#
# - use the dashboard delta between measured and predicted MPG to diagnose whether one vehicle segment, such as electrified vehicles, needs a separate regression treatment.
#
# Include clear instructions for how to run the app locally.

# %%
# TODO: create your Streamlit app.
#
# Suggested filename:
#   fuel_economy_final_app.py
#
# Suggested command:
#   streamlit run fuel_economy_final_app.py
#
# Make sure the dashboard shows measured MPG relative to predicted MPG
# and that your classification / regression feature rankings with SelectKBest
# are discussed in the notebook writeup.

# %% [markdown]
# ## 10. Deliverables Checklist
#
# Before submission, confirm that you have included:
#
# - a completed notebook with explanations
# - model evaluation tables and figures
# - a working Streamlit app
# - a short summary memo
# - instructions for running Ollama and the app locally
